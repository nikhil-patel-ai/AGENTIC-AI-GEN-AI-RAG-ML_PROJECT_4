# %% [markdown]
# # print is use for answer

# %%
4 + 8
8 - 6
20 * 5
# Out:
# 100

# %%
print(4 + 8)
print(8 - 6)
print(20 * 5)
# Out:
# 12
# 2
# 100

# %%
a = 5 
b = 8
print(a)
print(b)
# Out:
# 5
# 8

# %%
print(a,b)
# Out:
# 5 8

# %%
c = 24
print(a)
print(b)
print(c)
# Out:
# 5
# 8
# 24

# %%
print(a,b,c)
# Out:
# 5 8 24

# %%
print(10) 
print(10,20) 
print('python') 
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
print()

# %%
num1=50
num2=60
add=num1+num2
print(add)
# Out:
# 110

# %%
num1=50
num2=60
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 50 and 60 is= 110

# %%
num1=50
num2=60
num3=80
add=num1+num2+num3
print('The addition of',num1,'and',num2,'and',num3,'is=',add)
# Out:
# The addition of 50 and 60 and 80 is= 190

# %%
name='Python '
age=21
city='hyderbad city'

print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is Python  and i am 21 years old form hyderbad city

# %%
num1=50
num2=60
add=num1+num2 
print(add)
# Out:
# 110

# %% [markdown]
# ## print result with string :

# %%
num1=50
num2=60
add=num1+num2 
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 50 and 60 is= 110

# %% [markdown]
# # print() with format method :

# %%
num1=50
num2=60
add=num1+num2 
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 50 and 60 is= 110

# %% [markdown]
# - ### first deside how the print statement should be
# - ### like:- The addition of 20 and 30 is = 50
# - ### then replace the variable position with curly brackets { }
# - ### then appply .format(val1,val2,....val-n methodm

# %%
num1=50
num2=60
num3=70
num4=80
add=num1+num2+num3+num4
print('The addition of {} and {} and {} and {} is= {}'.format(num1,num2,num3,num4,add))
# Out:
# The addition of 50 and 60 and 70 and 80 is= 260

# %%
num1=222 
num2=23
num3=440 
avg=(num1+num2+num3)/3    # or we can use avg=round(num1+num2+num3)/3,2) 
avg1=round((num1+num2+num3)/3,2) 
 # The avrage of num1,num2,num3 is = avg 
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3, 
avg,avg1))    # here we can use round(avg,2) also
# Out:
# The avrage of 222, 23, and 440 is= 228.33333333333334 or 228.33

# %%
round(avg,2)    # round of till 2 digite after decimal
# Out:
# 228.33

# %% [markdown]
# ### More short format meythod(f string method)
# - #### variable should be in curly braces
# - #### and write everything inside quots ''
# - #### at starting simpaly add f

# %%
num1=20 
num2=30
add=num1+num2 
print(f'The addition of {num1} and {num2} is= {add}')    # alwase prefer this
# Out:
# The addition of 20 and 30 is= 50

# %%
name='Python' 
age=21 
city='hyderabad' 
  # Hellow my name is python and i am 10 year old from hydrabad 
print(f'Hellow my name is {name} and i am {age} year old from {city}')
# Out:
# Hellow my name is Python and i am 21 year old from hyderabad

# %%
num1=200 
num2=5
num3=564 
avg=round((num1+num2+num3)/3,2)    # or we can use avg=round(num1+num2+num3)/3,2) 
  # The avrage of num1,num2,num3 is = avg 
print(f'The average of {num1},{num2},{num3} is = {avg}')
# Out:
# The average of 200,5,564 is = 256.33

# %%
# lets combine all 
num1=55 
num2=67 
add = num1+ num2 
print('The addition of',num1,'and',num2,'is=',add) 
print('The addition of {} and {} is= {}'.format(num1,num2,add)) 
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 55 and 67 is= 122
# The addition of 55 and 67 is= 122
# The addition of 55 and 67 is= 122

# %% [markdown]
# ## end statement :

# %%
print('Hello')    # first statement
print('Good Evening')    # 2nd statement
# Out:
# Hello
# Good Evening

# %% [markdown]
# ### i want print like:- hellow good morning

# %% [markdown]
# - #### Here we will use end statement that joint line from end of one string to starting of other string

# %%
print('hello', end=' ') # 1st statement 
print('world good day') # 2nd statement
# Out:
# hello world good day

# %%
print('hello', end=' ++++ ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello ++++ world good day

# %% [markdown]
# ## seprator :
#  - ### here one print statement only we use
#  - ### insisde one print statement we have multipal values
#  - ### we want to seperate these multipal values with anything

# %%
print(' hello ',' hii ',' how are you',sep=' ---> ')
# Out:
#  hello  --->  hii  --->  how are you

# %%
print('hello','hi','how are you',sep=' ***** ')
# Out:
# hello ***** hi ***** how are you

# %%
print('hello','hi','how are you',sep=' & ')
# Out:
# hello & hi & how are you

# %%
print('hello','hi','how are you',sep=' @ ')
# Out:
# hello @ hi @ how are you

# %%
print('Hello','hi','How are you',sep=' ')
# Out:
# Hello hi How are you

# %%
print(5,'.')    # . is far from 3 so here we will use sep method
# Out:
# 5 .

# %%
print(1,2,end=' ') 
print(3,'.',sep='') 
# will print 1 2 3.
# Out:
# 1 2 3.

# %% [markdown]
# # print() completed
