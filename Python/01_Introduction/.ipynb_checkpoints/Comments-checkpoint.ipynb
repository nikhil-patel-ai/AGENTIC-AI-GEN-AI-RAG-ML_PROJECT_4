# %% [markdown]
# # Python Comments

# %% [raw]
# #This is a single line comment
# #Use hash for comment
# #Python supports single line and multi-line comments
# #Single and double quotes for single line comments and triple quotes for multi-line comments
# #Comments is mostly used to explain codes

# %% [markdown]
# ## Single and double qoutes for single line comments example

# %%
c = 90
'This is comments in single quotes for single line'
# Out:
# 90

# %%
"This is comments in single quotes for single line"
# Out:
# 'This is comments in single quotes for single line'

# %% [markdown]
# ## Multi-line Comments

# %%
'''
Myself Nikhil Patel
I'm from Madhya Pradesh
I am currently Learning Full Stack Data Science with Gen AI 
'''
# Out:
# "\nMyself Nikhil Patel\nI'm from Madhya Pradesh\nI am currently Learning Full Stack Data Science with Gen AI \n"

# %% [raw]
# -we can also use tripple quotes in single line comments
