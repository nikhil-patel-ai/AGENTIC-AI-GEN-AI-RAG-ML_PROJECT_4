# %% [markdown]
# # Number System :

# %% [markdown]
# - ### Binary - (0-1)
# - ### Octal - (0-7)
# - ### Decimal - (0-9)
# - ### Hexadecimal - (0-9 then (a-f or A-F))

# %%
25
# Out:
# 25

# %%
bin(25)   # we convert decimal number system to binary number system
# Out:
# '0b11001'

# %%
int(0b11001)    # convrt binery number system to decimal number system
# Out:
# 25

# %%
oct(25)     # decimal number system to octal number system
# Out:
# '0o31'

# %%
int(0o31)    # convert octal number system to decimal number system
# Out:
# 25

# %%
hex(1)    # number to hexadecimal convert
# Out:
# '0x1'

# %%
hex(2)    # Decimal  to hexadecimal conversion
# Out:
# '0x2'

# %%
hex(8)
# Out:
# '0x8'

# %%
hex(9)
# Out:
# '0x9'

# %%
hex(10)
# Out:
# '0xa'

# %%
hex(11)
# Out:
# '0xb'

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(14)
# Out:
# '0xe'

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x9)    # hexadecimal to integer(number) convert
# Out:
# 9

# %%
int(0x19)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %% [markdown]
# ### Binary :

# %% [markdown]
# - #### Binary - Octal :

# %%
oct(0b11001)
# Out:
# '0o31'

# %% [markdown]
# - #### Binary - Decimal :

# %%
int(0b11001)
# Out:
# 25

# %% [markdown]
# - #### Binary - Hexadecimal :

# %%
hex (0b11001)
# Out:
# '0x19'

# %% [markdown]
# ### Octal :

# %% [markdown]
# - #### Octal - Binary :

# %%
bin(0o31)
# Out:
# '0b11001'

# %% [markdown]
# - #### Octal - Decimal :

# %%
int(0o31)
# Out:
# 25

# %% [markdown]
# - #### Octal - Hexadecimal :

# %%
hex(0o31)
# Out:
# '0x19'

# %% [markdown]
# ### Decimal :
#  - #### Decimal - Binary :

# %%
bin(45)
# Out:
# '0b101101'

# %% [markdown]
# - #### Decimal - Octal :

# %%
oct(45)
# Out:
# '0o55'

# %% [markdown]
# - #### Decimal - Hexadecimal :

# %%
hex(45)
# Out:
# '0x2d'

# %% [markdown]
# ### Hexadecimal :
#  - #### Hexadecimal - Binary :

# %%
bin(0x2d)
# Out:
# '0b101101'

# %% [markdown]
# - #### Hexadecimal - Octal :

# %%
oct(0x2d)
# Out:
# '0o55'

# %% [markdown]
# - #### Hexadecimal - Decimal :

# %%
int(0x2d)
# Out:
# 45

# %% [markdown]
# ## Number System Completed

# %% [markdown]
# # Bitwise operators :

# %% [markdown]
# ### 1. Complement :

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
~18
# Out:
# -19

# %% [markdown]
# ### 2. AND (&) :

# %%
12 & 13
# Out:
# 12

# %% [markdown]
# #### 3. OR(|) :

# %%
12 | 13
# Out:
# 13

# %% [markdown]
# ### 4. XOR (^) :

# %%
12 ^ 13
# Out:
# 1

# %% [markdown]
# ### 5. Left Shift :

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %% [markdown]
# ### 6. Right Shift :

# %%
12 >> 1
# Out:
# 6

# %%
12 >> 2
# Out:
# 3

# %%
12 >> 3
# Out:
# 1

# %%
12 >> 4
# Out:
# 0

# %%
12 >> 5
# Out:
# 0

# %% [markdown]
# ## completed bitwise operator
