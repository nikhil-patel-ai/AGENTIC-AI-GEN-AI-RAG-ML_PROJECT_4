# %% [markdown]
# # String :
#   + ### A string is a sequence of characters used to represent text, such as words or sentences.
#
#   #### Example :

# %%
s = welcome to string
# Out:
#   Cell In[7], line 1
#     s = welcome to string
#                 ^
# SyntaxError: invalid syntax

# %%
s1 = 'abcd' # single quotes
s1
# Out:
# 'abcd'

# %%
type(s1)
# Out:
# str

# %%
s2 = "nit-lab-practice single quotes"    #double quotes
print(s2)
print(type(s2))
id(s2)
# Out:
# nit-lab-practice
# <class 'str'>
# 2875229763888

# %%
s3 = "nit-lab-practice double quotes"    #triple quotes
print(s3)
print(type(s3))
id(s3)
# Out:
# nit-lab-practice
# <class 'str'>
# 2875192277744

# %%
s3 = '''nit-lab-practice triple quotes'''    #triple quotes
print(s3)
print(type(s3))
id(s3)
# Out:
# nit-lab-practice triple quotes
# <class 'str'>
# 2875250268304

# %% [markdown]
# + ### Test case 1

# %%
s4 = ' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI
    This is test for single quotes in 
    multiple line '         # its occures error
# Out:
#   Cell In[16], line 1
#     s4 = ' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# + ### Test case 2

# %%
s5 = '' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI
    This is test for double quotes in 
    multiple line ''          # its occures error
# Out:
#   Cell In[21], line 1
#     s5 = '' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# + ### Test case 3

# %%
s6 = ''' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI
    This is test for single quotes in 
    multiple line '''       # its run without error
s6
# Out:
# ' Welcome to the Naresh IT FSDS With Gen-AI & Agentic-AI\n    This is test for single quotes in \n    multiple line '

# %% [markdown]
# + # string indexing & slicing

# %%
str1 = 'welcome'
str1
# Out:
# 'welcome'

# %% [markdown]
# + #### Define string using single quotes :

# %%
mystr = 'Hello World' # Define string using single quotes 
print(mystr)
# Out:
# Hello World

# %% [markdown]
# + #### Define string using double quotes :

# %%
mystr1 = "Hello World" # Define string using double quotes 
print(mystr1)
# Out:
# Hello World

# %% [markdown]
# + #### Define string using triple quotes :

# %%
mystr2 = ''' Hello
             World '''    # Define sting using double quotes
mystr2
# Out:
# ' Hello\n             World '

# %% [markdown]
# - #### Redefining mystr string

# %%
mystr = ('Happy ' 
'Monday ' 
'Everyone') 
print(mystr)
# Out:
# Happy Monday Everyone

# %% [markdown]
# - #### To print one string to multiple time

# %%
mystr2 = 'Woohoo ' 
mystr2 = mystr2*5 
mystr2
# Out:
# 'Woohoo Woohoo Woohoo Woohoo Woohoo '

# %% [markdown]
# - #### To check length of string

# %%
len(mystr2) # Length of string
# Out:
# 35

# %% [markdown]
# + ## Note :

# %% [markdown]
# ### 1. Creation and Syntax :
# - #### Quote Flexibility : Use single ('...') or double ("...") quotes to create a string. Both work identically.
# - #### Quote Nesting : Use double quotes outside if the string contains a single quote (e.g., "It's okay"), and vice versa.
# - #### Multiline Strings : Use triple quotes ("""...""" or '''...''') to span text across multiple lines.
# - #### Escape Characters: Use a backslash (\) to insert special characters like newlines (\n) or literal quotes (\').
# - #### Raw Strings : Prefix a string with r (e.g., r"C:\Users\name") to treat backslashes as literal characters

# %% [markdown]
# ### 2. Immutability
# - #### Read-Only Data : Python strings are immutable. You cannot modify, add, or delete characters in place.
# - #### Creating New Output : Any operation that alters a string (like changing capitalization) creates an entirely new string in memory.

# %% [markdown]
# ### 3. Indexing and Slicing :
# - #### Zero-Based Indexing : The first character is always at index 0, the second is at 1, and so on.
# - #### Negative Indexing : Access characters from the end of the string starting at -1 (the last character).
# - #### Slicing Syntax : Extract a substring using [start:stop], where the start index is inclusive and the stop index is exclusive.
# - #### Out-of-Bounds Error : Accessing a single index that does not exist throws an IndexError. Slicing out of bounds returns an empty string without crashing.

# %% [markdown]
# ### 4. Basic Operations :
# - #### Concatenation : Join strings together using the + operator (e.g., "Hello " + "World").
# - #### Replication : Repeat a string multiple times by multiplying it with an integer (e.g., "Hi" * 3 outputs "HiHiHi").
# - #### Type Constraints : You cannot concatenate a string directly with a number; you must convert the number first using str(5).
# - #### Length : Find the total number of characters (including spaces and punctuation) using the len() function.

# %%
st1 = 'Welcome to the string indexing & slicing in python'
st1
# Out:
# 'Welcome to the string indexing & slicing in python'

# %%
st2 = 'Welcome'
st2
# Out:
# 'Welcome'

# %%
st2[0]
# Out:
# 'W'

# %%
st2[5]
# Out:
# 'm'

# %%
st2[2]
# Out:
# 'l'

# %%
st2[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 st2[9]
#
# IndexError: string index out of range

# %% [markdown]
# ## String indexing type :
# - #### Forward indexing : Moves from left to right, starting at 0.
# - #### Backward indexing : Moves from right to left, starting at -1.

# %% [markdown]
# #### 1. Forward indexing :

# %%
str2 = 'Naresh IT'
str2
# Out:
# 'Naresh IT'

# %%
str2[0]
str2
# Out:
# 'Naresh IT'

# %%
str2[0]    # First character in string "str2"
# Out:
# 'N'

# %%
str2[1]
# Out:
# 'a'

# %%
str2[-1]    # Last character in string
# Out:
# 'T'

# %%
str2[6]    # Fetch 7th element of the string
# Out:
# ' '

# %%
str2[len(str2)-1]    # Last character in string using len function
# Out:
# 'T'

# %%
print(str2[2],str2[3],str2[4],str2[5],str2[6],str2[7],str2[8])
# Out:
# r e s h   I T

# %%
str2[11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 str2[11]
#
# IndexError: string index out of range

# %% [markdown]
# #### 2. Backward indexing :

# %%
str2
# Out:
# 'Naresh IT'

# %%
str2[-1]    # First character of backward string
# Out:
# 'T'

# %%
str2[-6]
# Out:
# 'e'

# %%
print(str2[-2],str2[-3],str2[-4],str2[-5],str2[-6],str2[-7],str2[-8],str2[-9])
# Out:
# I   h s e r a N

# %%
print(str2[-9],str2[-8],str2[-7],str2[-6],str2[-5],str2[-4],str2[-3],str2[-2],str2[-1])
# Out:
# N a r e s h   I T

# %%
str2[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 str2[-10]
#
# IndexError: string index out of range

# %% [markdown]
# ## String Slicing :

# %%
str2
# Out:
# 'Naresh IT'

# %%
str2[:]    # print all value
# Out:
# 'Naresh IT'

# %%
str2[0:9] # String slicing - Fetch all characters from 0 to 5 index location exc
# Out:
# 'Naresh IT'

# %%
str2[6:12] # String slicing - Retreive all characters between 6 - 12 index location
# Out:
# ' IT'

# %%
str2[-4:] # Retreive last four characters of the string
# Out:
# 'h IT'

# %% [markdown]
# ##  Slicing Types (By Direction)
# ### Slicing changes its behavior completely based on the sign of your step value.
# - #### Positive Step Type (Forward Slicing)Rule : step is a positive integer (or omitted, defaulting to 1).
# - #### Direction : Moves left to right.
# - #### Requirement : start must be to the left of stop (index start < stop) to return data. If start >= stop, it returns an empty string "".

# %%
str2[0: ]    # Start at 0th index and print till end
# Out:
# 'Naresh IT'

# %%
str2[3:9]    # Start at 3rd index & end with (n-1)th index
# Out:
# 'esh IT'

# %%
str2[:4]     # Retreive first four characters of the string
# Out:
# 'Nare'

# %% [markdown]
# ### Negative Step Type (Backward Slicing)
# - #### Rule : step is a negative integer (e.g., -1, -2).
# - #### Direction : Moves right to left.
# - #### Requirement : start must be to the right of stop (index start > stop) to return data. If start <= stop, it returns an empty string "".

# %%
str2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 str2
#
# NameError: name 'str2' is not defined

# %%
str2[ :-1]     # Start with -1th index and prints till end
# Out:
# 'Naresh I'

# %%
str2[-6:]    # Retreive last six characters of the string
# Out:
# 'esh IT'

# %% [markdown]
# ## Advanced Slicing, Python Type-Casting :

# %% [markdown]
# ## Note :
# - #### 1- si[:] --> print all value.
# - #### 2- si[1 : 4] --print value from 1st index to 4th index
#    - ##### left index -- 1
#    - ##### right index -- 4 ( n-1)
#    - ##### [L : R] -- right index will be apply n-1 not left index
# - #### 3- si [ 2:] -- print the index value from 2nd index till end.
# - #### 4- si[0:7:2] -- print the 2nd index value from 0 to 7
# - ####

# %%
str2[0:7:2]    #step slicing
# Out:
# 'Nrs '

# %%
str2
# Out:
# 'Naresh IT'

# %%
str2[-5 : -1]    # Start at -5th index & end -1st index
# Out:
# 'sh I'

# %%
str2[::2]    # Start at 0th index, print till end & every 2nd index will print  [start:end:step]
# Out:
# 'Nrs T'

# %%
str2[::3]    # Start at 0th index, print till end & every 3rd index will print  [start:end:step]
# Out:
# 'Ne '

# %%
str2[::-1]    # Start at -1th index, print till end & every 2nd index will print [start:end:step]
# Out:
# 'TI hseraN'

# %% [markdown]
# ##### string indexing, slicing, forward slicing, backward slicing, step slicing, advance slicing

# %% [markdown]
# # Python type casting :

# %% [markdown]
# - ### In Python, typecasting (or type conversion) changes a value from one data type to another. Python handles this in two ways: implicit conversion (automatic) and explicit conversion (manual).

# %%
110.0
# Out:
# 110.0

# %%
int(110.34)    # we can convert float to int
# Out:
# 110

# %% [markdown]
# ### 1. All othet data type to integer data type casting :

# %%
int(234.44)    # float to int type casting
# Out:
# 234

# %%
int(True)    # bool to int type casting
# Out:
# 1

# %%
int(False)    # bool to int type casting
# Out:
# 0

# %%
int("23")    # number string to int casting
# Out:
# 23

# %%
int("ten")    # text string to int casting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int("ten")    # text string to int casting
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# - ##### Note :
#    - ##### Text string is not possible to type cast in int type
#    - ##### Also complex type is not possible to type cast in int type

# %% [markdown]
# ### 2. All othet data type to float data type casting :

# %%
float(220)    # int to float type casting
# Out:
# 220.0

# %%
float(True)    # bool to float type casting
# Out:
# 1.0

# %%
float(false)    # wrong bool to float type casting
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 float(false)    # wrong bool to float type casting
#
# NameError: name 'false' is not defined

# %%
float(False)    # bool to float type casting
# Out:
# 0.0

# %%
float(2+3j)    # complex to float type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float(2+3j)    # complex to float type casting
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('220')    # number string to float type casting
# Out:
# 220.0

# %%
float('ten')    # text string to float type casting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float('ten')    # text string to float type casting
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# - ##### Note :
#    - ##### Text string is not possible to type cast in float type
#    - ##### Also complex type is not possible to type cast in float typ

# %% [markdown]
# ### 3. All othet data type to bool data type casting :

# %%
bool(23)    # int to bool type casting
# Out:
# True

# %%
bool(0)    # int to bool type casting
# Out:
# False

# %%
bool(4.5)    # float to bool type casting
# Out:
# True

# %%
bool('13')    # number string to bool type casting
# Out:
# True

# %%
bool('ten')    # text string to bool type casting
# Out:
# True

# %%
bool()    # empety to bool type casting
# Out:
# False

# %% [markdown]
# - #### Note : All type casting is possible to bool type casting

# %% [markdown]
# ### 4. All othet data type to string data type casting :

# %%
str(10)    # int to string type casting
# Out:
# '10'

# %%
str(32.23)    # float to string type casting
# Out:
# '32.23'

# %%
str(True)    # bool to string type casting
# Out:
# 'True'

# %%
str(False)    # bool to string type casting
# Out:
# 'False'

# %%
str(1+0j)    # complex to string type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 str(1,0j)    # complex to string type casting
#
# TypeError: str() argument 'encoding' must be str, not complex

# %% [markdown]
# ### 5. All othet data type to complex data type casting :

# %%
complex(2)    # int to complex type casting
# Out:
# (2+0j)

# %%
complex(3,4)    # int to complex type casting
# Out:
# (3+4j)

# %%
complex(2.4)    # float to complex type casting
# Out:
# (2.4+0j)

# %%
complex(3,4,5)    # int to complex type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 complex(3,4,5)    # int to complex type casting
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %% [markdown]
# - ##### complex() takes at most 2 arguments

# %%
complex(2.4,4.5)    # float to complex type casting
# Out:
# (2.4+4.5j)

# %%
complex(True)    # bool to complex type casting
# Out:
# (1+0j)

# %%
complex(False)    # bool to complex type casting
# Out:
# 0j

# %%
complex('10')    # number string to complex type casting
# Out:
# (10+0j)

# %%
complex('ten')    # text string to complex type casting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 complex('ten')    # text string to complex type casting
#
# ValueError: complex() arg is a malformed string

# %%
complex('12','13')    # multi number string to complex type casting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 complex('12','13')    # multi number string to complex type casting
#
# TypeError: complex() argument 'real' must be a real number, not str

# %% [markdown]
# - #### Note :
#   - ##### Text string is not accepted in complex type casting.
#   - ##### Only one string is accept in complex type casting.

# %% [markdown]
# # Python type casting is completed
