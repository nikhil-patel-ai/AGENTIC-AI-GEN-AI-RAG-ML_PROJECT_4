# %% [markdown]
# # LIST DATASTRUCTURE

# %%
l = []    # always remember use for lis
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %% [markdown]
# ## .append Function

# %%
l.append(20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 l.append(20,30,40)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l
# Out:
# []

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [20, 30, 40, 50]

# %%
len(l)
# Out:
# 4

# %%
l
# Out:
# [20, 30, 40, 50]

# %%
l.append(10)    # duplication is allowed
l
# Out:
# [20, 30, 40, 50, 10]

# %%
l1 =[10, 3.5, True, 1+3j, 'hello']
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello']

# %%
l1.append([1,2,3,4])   # nested list
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %% [markdown]
# ## .copy() function

# %%
l3 =l.copy()
l3
# Out:
# [20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
# Out:
# 2396528901632

# %%
print(id(l3))
# Out:
# 2396529335744

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [20, 30, 40, 50, 10]

# %% [markdown]
# ## .clear() function

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l
# Out:
# [20, 30, 40, 50, 10]

# %% [markdown]
# ## .clear() function

# %%
l.count(30)
# Out:
# 1

# %%
l.count(10)
# Out:
# 1

# %%
l
# Out:
# [20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
# Out:
# [20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ## .extend() function

# %%
l.extend(l1)
l
# Out:
# [20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
print(len(l))
print(len(l1))
# Out:
# 11
# 6

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ## .index() function

# %%
l.index(20)
# Out:
# 0

# %%
l1.index(1 + 3j)
# Out:
# 3

# %%
l1.index('hello')
# Out:
# 4

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 l1[6]
#
# IndexError: list index out of range

# %%
l1[4]
# Out:
# 'hello'

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[3:]
# Out:
# [(1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'hello']

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[-3]
# Out:
# (1+3j)

# %%
l1[-3:]
# Out:
# [(1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[::-1]   # reverse
# Out:
# [[1, 2, 3, 4], 'hello', (1+3j), True, 3.5, 10]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[::-2]
# Out:
# [[1, 2, 3, 4], (1+3j), 3.5]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[4]
# Out:
# 'hello'

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
# Out:
# h
# e
# l
# l
# o
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 6
#       2 print(l1[4][1])
#       3 print(l1[4][2])
#       4 print(l1[4][3])
#       5 print(l1[4][4])
# ----> 6 print(l1[4][5])
#
# IndexError: string index out of range

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[0] = 100
l1
# Out:
# [100, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
