# %% [markdown]
# # LIST DATASTRUCTURE

# %% [markdown]
# ### List creation

# %%
l = []    # This is empty list
l
# Out:
# []

# %%
type(l)    # checking type of l
# Out:
# list

# %%
len(l)    # length of l
# Out:
# 0

# %%
list2 = [10,30,60]    # List of integers numbers

# %%
list2
# Out:
# [10, 30, 60]

# %%
list3 = [10.77,30.66,60.89]    # List of float numbers

# %%
list3
# Out:
# [10.77, 30.66, 60.89]

# %%
list4 = ['one', 'two', 'three']    # List of strings
list4
# Out:
# ['one', 'two', 'three']

# %%
list5 = ['Nikhil', 21 ,[50, 100],[150, 90]]     # Nested Lists and multi type/mixed list
list5
# Out:
# ['Nikhil', 21, [50, 100], [150, 90]]

# %%
list6 = [100, 'Nikhil', 17.765]     # List of mixed data types 
list6
# Out:
# [100, 'Nikhil', 17.765]

# %%
list7 = ['Nikhil', 21 ,[70, 700],[50, 900] , {'Nikhil' , 'Kumar'}]    # Also this is mixed data type list
list7
# Out:
# ['Nikhil', 21, [70, 700], [50, 900], {'Kumar', 'Nikhil'}]

# %%
len(list6)    # Length of list
# Out:
# 3

# %%
l.append(10)     # add the value at the end
l
# Out:
# [10]

# %%
len(l)    # again checking the lenth of l
# Out:
# 1

# %% [markdown]
# ## .append Function

# %%
l.append(20,30,40)     # append funtion take only one argumen at a one time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 l.append(20,30,40)     # append funtion take only one argumen at a one time
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l   # printing list
# Out:
# [10]

# %%
l.append(20)    # add 20 at the end of the list 
l.append(30)    # add 30 after 20 because we have already add 20 at the end of the list l
l.append(40)    # same as privious
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l    # printing list
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)    # duplication is allowed
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 =[10, 3.5, True, 1+3j, 'hello']    # multiple data type is allowed in list
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello']

# %%
l1.append([1,2,3,4])   # adding list an existing list is called nested list
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ## .copy() function

# %%
l3 =l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
# Out:
# 2033004215232

# %%
print(id(l3))
# Out:
# 2033004990912

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [10, 20, 30, 40, 50, 10]

# %% [markdown]
# ## .clear() function

# %%
l3.clear()

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %% [markdown]
# ## .count() function

# %%
l.count(30)
# Out:
# 1

# %%
l.count(10)
# Out:
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ## .extend() function

# %%
l.extend(l1)    # it merge one list to another list
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
print(len(l))
print(len(l1))
# Out:
# 12
# 6

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)    # merging b1 to a1
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ## List Indexing
#   - ### Forward indexing -----> 0 1 2 3 4 5
#   - ### Backward indexing <----- -6 -5 -4 -3 -2 -1
# ### .index() function

# %%
l.index(20)
# Out:
# 1

# %%
l1.index(1 + 3j)
# Out:
# 3

# %%
l1.index('hello')
# Out:
# 4

# %% [markdown]
# ### Forward indexing

# %%
lst1 = [ 10, 20, 40, 80, 'Hello']
lst1
# Out:
# [10, 20, 40, 80, 'Hello']

# %%
lst1[0]    # Retreive first element of the list
# Out:
# 10

# %%
lst1[4][0]     # Nested indexing - Access the first character of the first list element
# Out:
# 'H'

# %%
lst1[-1]     # Last item of the list
# Out:
# 'Hello'

# %% [markdown]
# ### slicing

# %%
l1[:]
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 l1[6]
#
# IndexError: list index out of range

# %%
l1[4]    # printing 4th index
# Out:
# 'hello'

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[:3]    # start at 0th index and end with (n-1) -- (3-1)
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[3:]     # start with 3rd index and print till end
# Out:
# [(1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %% [markdown]
# ### steps slicing

# %%
l1[0:5:2]    # start with 0th index and end with {(n-1)---> (5-1)=4th index} and prints the second value
# Out:
# [10, True, 'hello']

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[-3]    # backward slicing prints -3rd index
# Out:
# (1+3j)

# %%
l1[-3:]    # start with -3rd index and print till -1st index
# Out:
# [(1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[::-1]   # print reverse list
# Out:
# [[1, 2, 3, 4], 'hello', (1+3j), True, 3.5, 10]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[::-2]    # print reverse, start with -1th, end is till end and every second value
# Out:
# [[1, 2, 3, 4], (1+3j), 3.5]

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[4]
# Out:
# 'hello'

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
print(l1[4][5])
# Out:
# h
# e
# l
# l
# o
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 6
#       2 print(l1[4][1])
#       3 print(l1[4][2])
#       4 print(l1[4][3])
#       5 print(l1[4][4])
# ----> 6 print(l1[4][5])
#
# IndexError: string index out of range

# %%
l1
# Out:
# [10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l1[0] = 100    # updating 0th index with value of 100
l1
# Out:
# [100, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l2 = [ 10,20,30]
l2[0]    # accesing 0th index of l2
# Out:
# 10

# %%
l2[0] = 100     # updating 0th index of l2 with value 100
l2
# Out:
# [100, 20, 30]

# %% [markdown]
# ## .insert() function

# %%
l2
# Out:
# [100, 20, 30]

# %%
l2.insert(2,25)    # insert funtion is used or the value adding with specific index

# %%
l2
# Out:
# [100, 20, 25, 30]

# %%
l2.insert(2,[1,2,3])     # we can also add list inside list

# %%
l2
# Out:
# [100, 20, [1, 2, 3], 25, 30]

# %%
l2.insert(3,5,6,7)    # adding multiple is not allowed in list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 l2.insert(3,5,6,7)    # adding multiple is not allowed in list
#
# TypeError: insert expected 2 arguments, got 4

# %% [markdown]
# ## .pop() Function

# %%
l2
# Out:
# [100, 20, [1, 2, 3], 25, 30]

# %%
l2.pop()    # pop function is used for remove and print that item
# Out:
# 30

# %%
l2
# Out:
# [100, 20, [1, 2, 3], 25]

# %%
l2.pop()    # if no argument, it remove by default last item in the index
# Out:
# 25

# %%
l2.pop(2)    # it remove 2rd index
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [100, 20]

# %% [markdown]
# ## .remove()

# %%
l = [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
l.remove(10)    # it remove with list value
l
# Out:
# [20, 30, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]

# %%
print(l)
print(l2)
# Out:
# [20, 30, 50, 10, 10, 3.5, True, (1+3j), 'hello', [1, 2, 3, 4]]
# [100, 20, [1, 2, 3]]

# %% [markdown]
# ### Join Lists

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']

# %%
print(list1)
print(list2)
# Out:
# ['one', 'two', 'three', 'four']
# ['five', 'six', 'seven', 'eight']

# %%
list3 = list1 + list2    # Join two lists by '+' operator 
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) #Append/add list2 with list1 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## .reverse() function

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()    # Reverse the list 
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] # Reverse the list 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
l3 = ['a', 'b', 'c', 'd']
l3
# Out:
# ['a', 'b', 'c', 'd']

# %%
l3.reverse()    # it print reverse order item

# %%
l3
# Out:
# ['d', 'c', 'b', 'a']

# %% [markdown]
# ## .sort() function

# %%
l =['10', '10', '10', '20', '30', '40', '50']

# %%
l.sort()    # it will sort at assending order
l
# Out:
# ['10', '10', '10', '20', '30', '40', '50']

# %%
lstn =  [9,5,2,99,12,88,34]
lstn
# Out:
# [9, 5, 2, 99, 12, 88, 34]

# %%
lstn.sort()    # Sort list in ascending order 
lstn
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
lstn.sort(reverse=True) # Sort list in descending order 
lstn
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
lst3 = [88,65,33,21,11,98] 
lst3
# Out:
# [88, 65, 33, 21, 11, 98]

# %%
sorted(lst3)    # Returns a new sorted list and doesn't change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %% [markdown]
# ### List membership

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l = [10, 10, 10, 20, 30, 40, 50]
l
# Out:
# [10, 10, 10, 20, 30, 40, 50]

# %%
10 in l
# Out:
# True

# %%
40 in l
# Out:
# True

# %%
100 in l
# Out:
# False

# %%
l
# Out:
# [10, 10, 10, 20, 30, 40, 50]

# %%
for i in l:
    print(i)
# Out:
# 10
# 10
# 10
# 20
# 30
# 40
# 50

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 10)
# (1, 10)
# (2, 10)
# (3, 20)
# (4, 30)
# (5, 40)
# (6, 50)

# %% [markdown]
# ### All/Any

# %% [markdown]
# ### All

# %%
L =[1,3,2,5,8]
L
# Out:
# [1, 3, 2, 5, 8]

# %%
all(L)
# Out:
# True

# %%
L.append(0)
L
# Out:
# [1, 3, 2, 5, 8, 0, 0]

# %%
all(L)
# Out:
# False

# %%
L.remove(0)
L
# Out:
# [1, 3, 2, 5, 8]

# %% [markdown]
# ### Any

# %%
any(L)
# Out:
# True

# %%
L.insert(1,0)
L
# Out:
# [1, 0, 3, 2, 5, 8]

# %%
any(L)
# Out:
# True

# %% [markdown]
# ## List is completed
