# %% [markdown]
# # Dictionary

# %%
d = {
    100:'nikhil', 
    200:'haresh', 
    300:'it'
}
d
# Out:
# {100: 'nikhil', 200: 'haresh', 300: 'it'}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# ## create a dictionary

# %%
dictmy = dict()     # empty dictionary 
dictmy
# Out:
# {}

# %%
type(dictmy)
# Out:
# dict

# %%
mydict = {
    1:'one' , 
    2:'two' , 
    3:'three'}    # dictionary with integer keys 
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
dict1 = {
    'A':'one',
    'B':'two',
    'C':'three'
}     # dictionary with character keys
dict1
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
dict2 = {
    1:'one',
    'A':'two',
    3:'three'
}    # dictionary with mixed key
dict1
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
dict2.keys()    # Return Dictionary Keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
dict2.values()     # Return Dictionary Values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
dict2.items()     # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
dict3 = {1:'one' , 2:'two' , 'A':['jorden' , 'john' , 'Maria']}     # dictionary with one key and multiple values
dict3
# Out:
# {1: 'one', 2: 'two', 'A': ['jorden', 'john', 'Maria']}

# %%
dict4 = {
    1:'one',
    2:'two',
    'A': ['msd', 'kapil', 'rohit'], 
    'B': ('car', 'bmw', 'audi')
} 
dict4
# Out:
# {1: 'one',
#  2: 'two',
#  'A': ['msd', 'kapil', 'rohit'],
#  'B': ('car', 'bmw', 'audi')}

# %%
dict5 = { 
    1: 'one', 
    2: 'two', 
    'A': {'Name': 'ankit', 'Age': 20}, 
    'B': ('Bat', 'cat', 'hat')
} 
dict5
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'ankit', 'Age': 20},
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
dict5 = dict.fromkeys(keys)     # Create a dictionary from a sequence of keys 
dict5
# Out:
# {'c': None, 'a': None, 'd': None, 'b': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
mydict3 = dict.fromkeys(keys)     # Create a dictionary from a sequence of keys 
mydict3
# Out:
# {'c': None, 'a': None, 'd': None, 'b': None}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = 10 
mydict3 = dict.fromkeys(keys , value)     # Create a dictionary from a sequence of 
mydict3
# Out:
# {'c': 10, 'a': 10, 'd': 10, 'b': 10}

# %%
keys = {'a' , 'b' , 'c' , 'd'} 
value = [10,20,30] 
mydict3 = dict.fromkeys(keys , value)     # Create a dictionary from a sequence of 
mydict3
# Out:
# {'c': [10, 20, 30], 'a': [10, 20, 30], 'd': [10, 20, 30], 'b': [10, 20, 30]}

# %%
value.append(40) 
mydict3
# Out:
# {'c': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40]}

# %% [markdown]
# ### Accessing Items

# %%
mydict = {1:'one' , 2:'two' , 3:'three' , 4:'four'} 
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]    # Access item using key
# Out:
# 'one'

# %%
mydict.get(1)     # Access item using get() method
# Out:
# 'one'

# %%
mydict1 = {'Name':'John' , 'ID': 74123 , 'DOB': 1991 , 'job' :'Analyst'} 
mydict1
# Out:
# {'Name': 'John', 'ID': 74123, 'DOB': 1991, 'job': 'Analyst'}

# %%
mydict1['Name']     # Access item using key
# Out:
# 'John'

# %%
mydict1.get('job')     # Access item using get() method
# Out:
# 'Analyst'

# %% [markdown]
# ### Add, Remove & Change Items

# %%
mydict1 = {'Name':'MSD' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB'] = 1992     # Changing Dictionary Items 
mydict1['Address'] = 'Delhi' 
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1 = {'DOB':1995} 
mydict1.update(dict1) 
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst'     # Adding items in the dictionary 
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi', 'Job': 'Analyst'}

# %%
mydict1.pop('Job')     # Removing items in the dictionary using Pop method 
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem()     # A random item is removed
# Out:
# ('Address', 'Delhi')

# %%
mydict1
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1995}

# %%
del[mydict1['ID']]     # Removing item using del method 
mydict1
# Out:
# {'Name': 'MSD', 'DOB': 1995}

# %%
mydict1.clear()     # Delete all items of the dictionary using clear method 
mydict1
# Out:
# {}

# %%
del mydict1     # Delete the dictionary object 
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 del mydict1     # Delete the dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# ### Copy Dictionary

# %%
mydict = {'Name':'MSD' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'} 
mydict
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1 = mydict     # Create a new reference "mydict1"

# %%
id(mydict) , id(mydict1)     # The address of both mydict & mydict1 will be the same
# Out:
# (1112199813888, 1112199813888)

# %%
id(mydict) , id(mydict1)    # The address of both mydict & mydict1 will be the same
# Out:
# (1112199813888, 1112199813888)

# %%
mydict2 = mydict.copy()     # Create a copy of the dictionary

# %%
id(mydict2)     # The address of mydict2 will be different from mydict
# Out:
# 1112199811008

# %%
mydict['Address'] = 'Mumbai'

# %%
mydict
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict1     # mydict1 will be also impacted as it is pointing to the same dictionary
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict2     # Copy of list won't be impacted due to the changes made in the original
# Out:
# {'Name': 'MSD', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %% [markdown]
# ### Loop through a Dictionary

# %%
mydict1 = {'Name': 'Amit', 
'ID': 12345, 
'DOB': 1991, 
'Address': 'Hilsinki', 
'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Amit',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'Job': 'Analyst'}

# %%
for i in mydict1: 
    print(i , ':' , mydict1[i])     # Key & value pair
# Out:
# Name : Amit
# ID : 12345
# DOB : 1991
# Address : Hilsinki
# Job : Analyst

# %%
for i in mydict1: 
    print(mydict1[i])     # Dictionary items
# Out:
# Amit
# 12345
# 1991
# Hilsinki
# Analyst

# %% [markdown]
# ### Dictionary Membership

# %%
mydict1 = {'Name':'Deepak' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'} 
mydict1
# Out:
# {'Name': 'Deepak', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1      # Test if a key is in a dictionary or not.
# Out:
# True

# %%
'Deepak' in mydict1     # Membership test can be only done for keys.
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
# ### All / Any

# %% [markdown]
# #### The all() method returns:
#  - ##### True - If all all keys of the dictionary are true
#  - ##### False - If any key of the dictionary is false
# ##### The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Vikash' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'} 
mydict1
# Out:
# {'Name': 'Vikash', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1)     # Will Return false as one value is false (Value 0)
# Out:
# True
