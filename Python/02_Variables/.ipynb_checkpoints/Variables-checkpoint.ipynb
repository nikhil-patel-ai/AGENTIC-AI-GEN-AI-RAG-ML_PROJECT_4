# %% [markdown]
# # Variables

# %% [markdown]
# ### Syntax: variable_name = Value

# %%
v = 21
v
# Out:
# 21

# %%
v1 = "Nihil" 
v1
# Out:
# 'Nihil'

# %% [markdown]
# ## Rules For Variables

# %% [markdown]
# #### 1. Variable does not start with Number But Ends With Number

# %%
1v = 34  # SyntaxError
# Out:
#   Cell In[5], line 1
#     1v = 34  # SyntaxError
#     ^
# SyntaxError: invalid decimal literal

# %%
2var = 23
# Out:
#   Cell In[6], line 1
#     2var = 23
#     ^
# SyntaxError: invalid decimal literal

# %%
v1 = 34
v1
# Out:
# 34

# %%
var1 = 34
var1
# Out:
# 34

# %% [markdown]
# ## 2. Variable are Case Senstive

# %%
v = 12
V = 23
print(v)
print(V)
# Out:
# 12
# 23

# %%
var3 = 78
Var3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 var3 = 78
# ----> 2 Var3
#
# NameError: name 'Var3' is not defined

# %% [markdown]
# ## 3. Special Charactar Are Not Allowed Except Underscore(_)

# %%
name@ = "Nikhil"
# Out:
#   Cell In[13], line 1
#     name@ = "Nikhil"
#           ^
# SyntaxError: invalid syntax

# %%
name% = "Nikhil"
# Out:
#   Cell In[14], line 1
#     name% = "Nikhil"
#           ^
# SyntaxError: invalid syntax

# %%
name$ = "Nikhil"
# Out:
#   Cell In[15], line 1
#     name$ = "Nikhil"
#         ^
# SyntaxError: invalid syntax

# %%
name# = "Nikhil"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 name# = "Nikhil"
#
# NameError: name 'name' is not defined

# %%
_name = "Nikhil"
_name
# Out:
# 'Nikhil'

# %%
first_name = "Nikhil"
first_name
# Out:
# 'Nikhil'

# %%
age_ = 22
age_
# Out:
# 22

# %% [markdown]
# ## Keywords

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)  # for lenth of keyword
# Out:
# 35
